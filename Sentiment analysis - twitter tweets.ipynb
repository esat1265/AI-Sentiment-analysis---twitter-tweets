# %%
# !pip install twython
# Out:
# Requirement already satisfied: twython in c:\users\utilisateur\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from twython) (1.3.1)
# Requirement already satisfied: requests>=2.1.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from twython) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (1.26.9)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests-oauthlib>=0.4.0->twython) (3.2.2)

# %%
from twython import Twython

# %%
CONSUMER_KEY = '0pJRCT1emkOcrtxHl7lMN4N5A'
CONSUMER_SECRET = 'IS4Gxcx1aQ1c5Hyei5PSePLS37IcVmYBT8Qt1t4IOxmLIxJD42'

twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET)

# %%
results = twitter.search(q="qatar",count=100,lang="en")

# %%
results
# Out:
# {'statuses': [{'created_at': 'Fri Nov 11 20:20:53 +0000 2022',
#    'id': 1591164080412577794,
#    'id_str': '1591164080412577794',
#    'text': 'Spend a lot of time shouting about how wonderful my children are but so is my Dad - the epitome of hard work pays o… https://t.co/Lz5OeUKH8Q',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Lz5OeUKH8Q',
#       'expanded_url': 'https://twitter.com/i/web/status/1591164080412577794',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1138827361284214784,
#     'id_str': '1138827361284214784',
#     'name': 'Mrs Smith',
#     'screen_name': 'mrssmithlearns',
#     'location': 'Clackmannshire',
#     'description': 'Early Years Educator at @tillyps 👩🏼\u200d🏫🎨Mum 👦🏼👧🏼 Parental Engagement Lead 🌳 Advocate for play & championing children ✨ views are my own',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 575,
#     'friends_count': 1031,
#     'listed_count': 2,
#     'created_at': 'Wed Jun 12 15:16:16 +0000 2019',
#     'favourites_count': 3125,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2601,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1563902844180340739/7ogdIFgq_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1563902844180340739/7ogdIFgq_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1138827361284214784/1639914030',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 11 20:20:53 +0000 2022',
#    'id': 1591164078080536576,
#    'id_str': '1591164078080536576',
#    'text': 'Feeling so proud of all the progress Qatar made in just few years!❤️',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2945194033,
#     'id_str': '2945194033',
#     'name': '🦌',
#     'screen_name': 'damascanrose',
#     'location': '',
#     'description': 'between history books',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 40,
#     'friends_count': 73,
#     'listed_count': 2,
#     'created_at': 'Sat Dec 27 14:38:23 +0000 2014',
#     'favourites_count': 1018,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 518,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1584252359139627008/-yUDD0MC_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1584252359139627008/-yUDD0MC_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2945194033/1666450173',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 11 20:20:52 +0000 2022',
#    'id': 1591164074267914240,
#    'id_str': '1591164074267914240',
#    'text': 'RT @FIFAWorldCup: Introducing the AI League: FIFA World Cup Qatar 2022 edition! ⚽️ \n\nCoach 4-on-4 casual football with your AI-controlled t…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'FIFAWorldCup',
#       'name': 'FIFA World Cup',
#       'id': 138372303,
#       'id_str': '138372303',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 99682425,
#     'id_str': '99682425',
#     'name': 'JG',
#     'screen_name': 'JordanGosling',
#     'location': 'Auckland, New Zealand',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 87,
#     'friends_count': 297,
#     'listed_count': 2,
#     'created_at': 'Sun Dec 27 10:11:28 +0000 2009',
#     'favourites_count': 1043,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 541,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1582480614011256832/mm2iqL77_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1582480614011256832/mm2iqL77_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/99682425/1662335790',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 11 18:30:00 +0000 2022',
#     'id': 1591136174378258437,
#     'id_str': '1591136174378258437',
#     'text': 'Introducing the AI League: FIFA World Cup Qatar 2022 edition! ⚽️ \n\nCoach 4-on-4 casual football with your AI-contro… https://t.co/gbPmUZf9xD',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/gbPmUZf9xD',
#        'expanded_url': 'https://twitter.com/i/web/status/1591136174378258437',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://twitter.com" rel="nofollow">Twitter for Advertisers</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 138372303,
#      'id_str': '138372303',
#      'name': 'FIFA World Cup',
#      'screen_name': 'FIFAWorldCup',
#      'location': '',
#      'description': 'The official Twitter account of the FIFA World Cup! FIFA+: your home for all things football. Watch or stream for free ⬇️',
#      'url': 'https://t.co/JAG8y3gRYU',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/JAG8y3gRYU',
#          'expanded_url': 'https://www.fifa.com/tournaments/mens/worldcup/qatar2022',
#          'display_url': 'fifa.com/tournaments/me…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 9915975,
#      'friends_count': 588,
#      'listed_count': 14747,
#      'created_at': 'Thu Apr 29 10:58:07 +0000 2010',
#      'favourites_count': 1910,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 29501,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C6E2EE',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1511271691657392129/Vv8Wa4st_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1511271691657392129/Vv8Wa4st_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/138372303/1661959432',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DAECF4',
#      'profile_text_color': '663B12',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 126,
#     'favorite_count': 366,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 126,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 11 20:20:49 +0000 2022',
#    'id': 1591164060606660608,
#    'id_str': '1591164060606660608',
#    'text': 'RT @BukayoSaka87: My childhood dream to play in a World Cup has come true !\nQatar 2022. Let’s go @england 🦁🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f\n#GodsPlan🙏🏿 https://t.co…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'GodsPlan', 'indices': [115, 124]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'BukayoSaka87',
#       'name': 'Bukayo Saka',
#       'id': 1038874580956442625,
#       'id_str': '1038874580956442625',
#       'indices': [3, 16]},
#      {'screen_name': 'England',
#       'name': 'England',
#       'id': 1903382054,
#       'id_str': '1903382054',
#       'indices': [97, 105]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1566484712083886081,
#     'id_str': '1566484712083886081',
#     'name': 'John_Laughters',
#     'screen_name': 'John_Laughters',
#     'location': 'Lagos, Nigeria',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 23,
#     'friends_count': 506,
#     'listed_count': 0,
#     'created_at': 'Sun Sep 04 17:54:47 +0000 2022',
#     'favourites_count': 805,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 520,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1566488035176357888/Ph_29wK__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1566488035176357888/Ph_29wK__normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1566484712083886081/1662314826',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Nov 10 14:42:06 +0000 2022',
#     'id': 1590716433193107459,
#     'id_str': '1590716433193107459',
#     'text': 'My childhood dream to play in a World Cup has come true !\nQatar 2022. Let’s go @england 🦁🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f\n#GodsPlan🙏🏿 https://t.co/Lvd5aLFqRa',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'GodsPlan', 'indices': [97, 106]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'England',
#        'name': 'England',
#        'id': 1903382054,
#        'id_str': '1903382054',
#        'indices': [79, 87]}],
#      'urls': [],
#      'media': [{'id': 1590716359977172992,
#        'id_str': '1590716359977172992',
#        'indices': [109, 132],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1590716359977172992/pu/img/s5_fYsTPUUGSEDB_.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1590716359977172992/pu/img/s5_fYsTPUUGSEDB_.jpg',
#        'url': 'https://t.co/Lvd5aLFqRa',
#        'display_url': 'pic.twitter.com/Lvd5aLFqRa',
#        'expanded_url': 'https://twitter.com/BukayoSaka87/status/1590716433193107459/video/1',
#        'type': 'photo',
#        'sizes': {'large': {'w': 720, 'h': 900, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 720, 'h': 900, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1590716359977172992,
#        'id_str': '1590716359977172992',
#        'indices': [109, 132],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1590716359977172992/pu/img/s5_fYsTPUUGSEDB_.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1590716359977172992/pu/img/s5_fYsTPUUGSEDB_.jpg',
#        'url': 'https://t.co/Lvd5aLFqRa',
#        'display_url': 'pic.twitter.com/Lvd5aLFqRa',
#        'expanded_url': 'https://twitter.com/BukayoSaka87/status/1590716433193107459/video/1',
#        'type': 'video',
#        'sizes': {'large': {'w': 720, 'h': 900, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 720, 'h': 900, 'resize': 'fit'}},
#        'video_info': {'aspect_ratio': [4, 5],
#         'duration_millis': 31880,
#         'variants': [{'bitrate': 632000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1590716359977172992/pu/vid/320x400/KBxuOEVVEG0lmbnt.mp4?tag=12'},
#          {'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1590716359977172992/pu/vid/720x900/dORPGXf4s3gMFMIv.mp4?tag=12'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1590716359977172992/pu/pl/tF-nIjHrlfKua8Fz.m3u8?tag=12&container=fmp4'},
#          {'bitrate': 950000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1590716359977172992/pu/vid/480x600/R1mg5BdATNSgkVtx.mp4?tag=12'}]},
#        'additional_media_info': {'monetizable': False}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1038874580956442625,
#      'id_str': '1038874580956442625',
#      'name': 'Bukayo Saka',
#      'screen_name': 'BukayoSaka87',
#      'location': 'London, England',
#      'description': 'Footballer for @Arsenal.',
#      'url': 'https://t.co/HS3YyyZpt3',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/HS3YyyZpt3',
#          'expanded_url': 'http://instagram.com/bukayosaka87',
#          'display_url': 'instagram.com/bukayosaka87',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 936639,
#      'friends_count': 0,
#      'listed_count': 1041,
#      'created_at': 'Sun Sep 09 19:39:36 +0000 2018',
#      'favourites_count': 184,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 191,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1286767288859992067/P-xmi5go_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286767288859992067/P-xmi5go_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1038874580956442625/1603838064',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 8194,
#     'favorite_count': 53678,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 8194,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 11 20:20:48 +0000 2022',
#    'id': 1591164059130658818,
#    'id_str': '1591164059130658818',
#    'text': 'RT @FIFAWorldCup: Introducing the AI League: FIFA World Cup Qatar 2022 edition! ⚽️ \n\nCoach 4-on-4 casual football with your AI-controlled t…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'FIFAWorldCup',
#       'name': 'FIFA World Cup',
#       'id': 138372303,
#       'id_str': '138372303',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 190161291,
#     'id_str': '190161291',
#     'name': 'RichieRich 🦐',
#     'screen_name': 'QTRichieRich',
#     'location': 'NZ / UK',
#     'description': 'Senior Developer @ATEMCarClub. Founder https://t.co/CsoBGzjmSC. @Theprawns_xyz @futureversexyz @flufworld @altstatemachine @seekers_xyz @wearehume @partybear',
#     'url': 'https://t.co/19mRfb2muN',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/19mRfb2muN',
#         'expanded_url': 'https://www.richdeane.dev/',
#         'display_url': 'richdeane.dev',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/CsoBGzjmSC',
#         'expanded_url': 'http://theprawns.xyz',
#         'display_url': 'theprawns.xyz',
#         'indices': [39, 62]}]}},
#     'protected': False,
#     'followers_count': 886,
#     'friends_count': 501,
#     'listed_count': 10,
#     'created_at': 'Mon Sep 13 06:46:40 +0000 2010',
#     'favourites_count': 5897,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2481,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1587199030370930688/qF18xulB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1587199030370930688/qF18xulB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/190161291/1663580814',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 11 18:30:00 +0000 2022',
#     'id': 1591136174378258437,
#     'id_str': '1591136174378258437',
#     'text': 'Introducing the AI League: FIFA World Cup Qatar 2022 edition! ⚽️ \n\nCoach 4-on-4 casual football with your AI-contro… https://t.co/gbPmUZf9xD',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/gbPmUZf9xD',
#        'expanded_url': 'https://twitter.com/i/web/status/1591136174378258437',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://twitter.com" rel="nofollow">Twitter for Advertisers</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 138372303,
#      'id_str': '138372303',
#      'name': 'FIFA World Cup',
#      'screen_name': 'FIFAWorldCup',
#      'location': '',
#      'description': 'The official Twitter account of the FIFA World Cup! FIFA+: your home for all things football. Watch or stream for free ⬇️',
#      'url': 'https://t.co/JAG8y3gRYU',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/JAG8y3gRYU',
#          'expanded_url': 'https://www.fifa.com/tournaments/mens/worldcup/qatar2022',
#          'display_url': 'fifa.com/tournaments/me…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 9915975,
#      'friends_count': 588,
#      'listed_count': 14747,
#      'created_at': 'Thu Apr 29 10:58:07 +0000 2010',
#      'favourites_count': 1910,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 29501,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C6E2EE',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1511271691657392129/Vv8Wa4st_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1511271691657392129/Vv8Wa4st_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/138372303/1661959432',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DAECF4',
#      'profile_text_color': '663B12',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 126,
#     'favorite_count': 366,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 126,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 11 20:20:44 +0000 2022',
#    'id': 1591164042663825408,
#    'id_str': '1591164042663825408',
#    'text': 'RT @SaddickAdams: Issah Amadu has been Asante Kotoko kitman since 1994.\n\nAs an appreciation for his 28-year service, the club is rewarding…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SaddickAdams',
#       'name': 'Saddick Adams',
#       'id': 4033989881,
#       'id_str': '4033989881',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1324781449,
#     'id_str': '1324781449',
#     'name': 'Adaku nabi🇬🇭🇬',
#     'screen_name': 'Nii_YNWA',
#     'location': 'Anfield ',
#     'description': 'GOD is good. @TopLevelPod 🎙https://t.co/8PtsNrSj6j #AHOSC',
#     'url': 'https://t.co/1cSfM7VYZF',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/1cSfM7VYZF',
#         'expanded_url': 'http://liverpoolfc.com',
#         'display_url': 'liverpoolfc.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/8PtsNrSj6j',
#         'expanded_url': 'https://linktr.ee/TopLevelPod',
#         'display_url': 'linktr.ee/TopLevelPod',
#         'indices': [27, 50]}]}},
#     'protected': False,
#     'followers_count': 1240,
#     'friends_count': 578,
#     'listed_count': 9,
#     'created_at': 'Wed Apr 03 14:55:42 +0000 2013',
#     'favourites_count': 328276,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 115606,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1531668267793883136/pqkB5u96_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1531668267793883136/pqkB5u96_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1324781449/1644344137',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 11 14:24:59 +0000 2022',
#     'id': 1591074515593093120,
#     'id_str': '1591074515593093120',
#     'text': 'Issah Amadu has been Asante Kotoko kitman since 1994.\n\nAs an appreciation for his 28-year service, the club is rewa… https://t.co/OJ9jYZUz5Q',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/OJ9jYZUz5Q',
#        'expanded_url': 'https://twitter.com/i/web/status/1591074515593093120',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4033989881,
#      'id_str': '4033989881',
#      'name': 'Saddick Adams',
#      'screen_name': 'SaddickAdams',
#      'location': 'Accra, Ghana',
#      'description': 'Award-winning Sports Journalist | African Football |            SaddickAdams@yahoo.com',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 719168,
#      'friends_count': 581,
#      'listed_count': 194,
#      'created_at': 'Sat Oct 24 20:25:14 +0000 2015',
#      'favourites_count': 2754,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 40286,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1477867655180824576/AUpcpwoS_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1477867655180824576/AUpcpwoS_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4033989881/1619515881',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 907,
#     'favorite_count': 7363,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 907,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 11 20:20:43 +0000 2022',
#    'id': 1591164036418502656,
#    'id_str': '1591164036418502656',
#    'text': 'RT @MickyJnr__: Zambian referee Janny Sikazwe has been selected to officiate at the World Cup in Qatar. 🚨🇿🇲\n\n#WorldCupwithMicky I #WorldCup…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'WorldCupwithMicky',
#       'indices': [109, 127]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MickyJnr__',
#       'name': 'Micky Jnr ✪',
#       'id': 1271101226718035977,
#       'id_str': '1271101226718035977',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1530483317883158534,
#     'id_str': '1530483317883158534',
#     'name': 'B@D GIRL ❣',
#     'screen_name': 'Salha__official',
#     'location': '',
#     'description': '❣️❣️❣️❣️ \n\nThe originator of the hashtag #LeoTupoNa\n\n@Arsenal',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5878,
#     'friends_count': 343,
#     'listed_count': 0,
#     'created_at': 'Sat May 28 09:37:32 +0000 2022',
#     'favourites_count': 12824,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 21013,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1590641491009060865/F8-HeHK-_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590641491009060865/F8-HeHK-_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1530483317883158534/1667280315',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 11 20:17:46 +0000 2022',
#     'id': 1591163295847034882,
#     'id_str': '1591163295847034882',
#     'text': 'Zambian referee Janny Sikazwe has been selected to officiate at the World Cup in Qatar. 🚨🇿🇲\n\n#WorldCupwithMicky I… https://t.co/FnIkbTQICG',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'WorldCupwithMicky',
#        'indices': [93, 111]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/FnIkbTQICG',
#        'expanded_url': 'https://twitter.com/i/web/status/1591163295847034882',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [115, 138]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1271101226718035977,
#      'id_str': '1271101226718035977',
#      'name': 'Micky Jnr ✪',
#      'screen_name': 'MickyJnr__',
#      'location': '🇬🇭🇪🇬🇹🇳🇿🇦🇲🇦🇨🇲🇳🇦',
#      'description': 'Leading African Football Journalist || Transfer Expert || @alahly ❤️ || @caf_online Media Expert || Writer || Media Manager || Travel Junkie || #CFC 💙',
#      'url': 'https://t.co/syhd8Re5Z4',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/syhd8Re5Z4',
#          'expanded_url': 'https://www.facebook.com/MickyJnrAF',
#          'display_url': 'facebook.com/MickyJnrAF',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 96446,
#      'friends_count': 253,
#      'listed_count': 70,
#      'created_at': 'Thu Jun 11 15:25:34 +0000 2020',
#      'favourites_count': 20693,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 20033,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1578651464339279873/RvpKxvBf_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1578651464339279873/RvpKxvBf_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1271101226718035977/1591890334',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 32,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 11 20:20:43 +0000 2022',
#    'id': 1591164035437039616,
#    'id_str': '1591164035437039616',
#    'text': 'RT @Masego: Can we agree that Qatar bought this hosting?',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Masego',
#       'name': 'Masego',
#       'id': 22005210,
#       'id_str': '22005210',
#       'indices': [3, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 17038049,
#     'id_str': '17038049',
#     'name': 'Saberah Gumede',
#     'screen_name': 'Saberah',
#     'location': 'South Africa',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2146,
#     'friends_count': 3006,
#     'listed_count': 18,
#     'created_at': 'Wed Oct 29 08:37:17 +0000 2008',
#     'favourites_count': 208799,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 177142,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1175026100252094464/Kq1e5uBy_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1175026100252094464/Kq1e5uBy_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17038049/1417767846',
#     'profile_link_color': '2FC2EF',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 11 17:16:25 +0000 2022',
#     'id': 1591117656702169088,
#     'id_str': '1591117656702169088',
#     'text': 'Can we agree that Qatar bought this hosting?',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://itunes.apple.com/us/app/twitter/id409789998?mt=12" rel="nofollow">Twitter for Mac</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 22005210,
#      'id_str': '22005210',
#      'name': 'Masego',
#      'screen_name': 'Masego',
#      'location': 'Sandton, Johannesburg',
#      'description': 'Life’s too short for cheap wine and ugly shoes!',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 12081,
#      'friends_count': 1669,
#      'listed_count': 23,
#      'created_at': 'Thu Feb 26 12:56:57 +0000 2009',
#      'favourites_count': 15548,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 34639,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F48A8C',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/832838236074569728/FX5iW1e6_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/832838236074569728/FX5iW1e6_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/22005210/1644894457',
#      'profile_link_color': 'F36C80',
#      'profile_sidebar_border_color': '44094B',
#      'profile_sidebar_fill_color': 'BC215D',
#      'profile_text_color': 'E44E77',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 59,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 11 20:20:42 +0000 2022',
#    'id': 1591164034006790146,
#    'id_str': '1591164034006790146',
#    'text': '@Raffaldo @AnfieldEdition @Independent Is it? Then why were you DMing banned FIFA committee member Mohammed Bin Ham… https://t.co/J7PydY0ft4',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Raffaldo',
#       'name': 'Raffaldo',
#       'id': 74683917,
#       'id_str': '74683917',
#       'indices': [0, 9]},
#      {'screen_name': 'AnfieldEdition',
#       'name': 'Anfield Edition',
#       'id': 4581796174,
#       'id_str': '4581796174',
#       'indices': [10, 25]},
#      {'screen_name': 'Independent',
#       'name': 'The Independent',
#       'id': 16973333,
#       'id_str': '16973333',
#       'indices': [26, 38]}],
#     'urls': [{'url': 'https://t.co/J7PydY0ft4',
#       'expanded_url': 'https://twitter.com/i/web/status/1591164034006790146',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1590939058636820480,
#    'in_reply_to_status_id_str': '1590939058636820480',
#    'in_reply_to_user_id': 74683917,
#    'in_reply_to_user_id_str': '74683917',
#    'in_reply_to_screen_name': 'Raffaldo',
#    'user': {'id': 340107820,
#     'id_str': '340107820',
#     'name': 'Garen Torossian',
#     'screen_name': 'GoldenBoyyyyy',
#     'location': 'Detroit',
#     'description': 'Manchester United',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 213,
#     'friends_count': 556,
#     'listed_count': 0,
#     'created_at': 'Fri Jul 22 04:32:12 +0000 2011',
#     'favourites_count': 1039,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 8653,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000282532512/5cb42daa5ce39e320f812ecdf68cd44a_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000282532512/5cb42daa5ce39e320f812ecdf68cd44a_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/340107820/1419634359',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
# ...
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Nov 10 23:14:48 +0000 2022',
#     'id': 1590845458771058689,
#     'id_str': '1590845458771058689',
#     'text': 'Ronald Araujo IS on the plane to Qatar for Uruguay ✈️🇺🇾\n\nHe underwent surgery in late September for his right thigh… https://t.co/dRkrKjlyrS',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/dRkrKjlyrS',
#        'expanded_url': 'https://twitter.com/i/web/status/1590845458771058689',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 18091004,
#      'id_str': '18091004',
#      'name': 'ESPN FC',
#      'screen_name': 'ESPNFC',
#      'location': '',
#      'description': "Meet the USMNT's Class of 2022 👀👇",
#      'url': 'https://t.co/o9KEIwOMtx',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/o9KEIwOMtx',
#          'expanded_url': 'https://www.espn.com/soccer/united-states-usa/story/4795181/2022-world-cup-usmnt-roster-inside-the-q',
#          'display_url': 'espn.com/soccer/united-…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 6634848,
#      'friends_count': 613,
#      'listed_count': 13220,
#      'created_at': 'Sat Dec 13 01:33:04 +0000 2008',
#      'favourites_count': 901,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 151528,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '381020',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/993576884498849792/zH7kViGI_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/993576884498849792/zH7kViGI_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18091004/1626211424',
#      'profile_link_color': '4A913C',
#      'profile_sidebar_border_color': 'D1CA8E',
#      'profile_sidebar_fill_color': '9DB381',
#      'profile_text_color': '39213B',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 672,
#     'favorite_count': 13301,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 672,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 11 20:17:53 +0000 2022',
#    'id': 1591163325693366272,
#    'id_str': '1591163325693366272',
#    'text': '@iiixrx Qatari gay teens aren’t frightened and scared when the country’s World Cup ambassador says being gay is ‘da… https://t.co/sbFUgLrOWy',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'iiixrx',
#       'name': 'rue',
#       'id': 748697992849489920,
#       'id_str': '748697992849489920',
#       'indices': [0, 7]}],
#     'urls': [{'url': 'https://t.co/sbFUgLrOWy',
#       'expanded_url': 'https://twitter.com/i/web/status/1591163325693366272',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1591159393600819200,
#    'in_reply_to_status_id_str': '1591159393600819200',
#    'in_reply_to_user_id': 748697992849489920,
#    'in_reply_to_user_id_str': '748697992849489920',
#    'in_reply_to_screen_name': 'iiixrx',
#    'user': {'id': 972885352624115717,
#     'id_str': '972885352624115717',
#     'name': 'Luke Fernandes',
#     'screen_name': 'LukeFernandes9',
#     'location': 'Hammersmith, London',
#     'description': 'Corbynista / remainer 🏳️\u200d🌈🇵🇸',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 266,
#     'friends_count': 487,
#     'listed_count': 0,
#     'created_at': 'Sun Mar 11 17:21:58 +0000 2018',
#     'favourites_count': 1503,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 349,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1410353330707124225/lcy9NOuc_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1410353330707124225/lcy9NOuc_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/972885352624115717/1520790113',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Nov 11 20:17:53 +0000 2022',
#    'id': 1591163324414144513,
#    'id_str': '1591163324414144513',
#    'text': 'RT @Memphis: Worldcup Qatar 🇶🇦 2022! \nWe coming! 🧘🏽\u200d♂️🙏🏽 https://t.co/MrC3uI2aps',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Memphis',
#       'name': 'Memphis Depay',
#       'id': 279966754,
#       'id_str': '279966754',
#       'indices': [3, 11]}],
#     'urls': [],
#     'media': [{'id': 1591101981887799297,
#       'id_str': '1591101981887799297',
#       'indices': [57, 80],
#       'media_url': 'http://pbs.twimg.com/media/FhS60o_XoAECw0p.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FhS60o_XoAECw0p.jpg',
#       'url': 'https://t.co/MrC3uI2aps',
#       'display_url': 'pic.twitter.com/MrC3uI2aps',
#       'expanded_url': 'https://twitter.com/Memphis/status/1591101988766642176/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1080, 'h': 1350, 'resize': 'fit'},
#        'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 960, 'h': 1200, 'resize': 'fit'}},
#       'source_status_id': 1591101988766642176,
#       'source_status_id_str': '1591101988766642176',
#       'source_user_id': 279966754,
#       'source_user_id_str': '279966754'}]},
#    'extended_entities': {'media': [{'id': 1591101981887799297,
#       'id_str': '1591101981887799297',
#       'indices': [57, 80],
#       'media_url': 'http://pbs.twimg.com/media/FhS60o_XoAECw0p.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FhS60o_XoAECw0p.jpg',
#       'url': 'https://t.co/MrC3uI2aps',
#       'display_url': 'pic.twitter.com/MrC3uI2aps',
#       'expanded_url': 'https://twitter.com/Memphis/status/1591101988766642176/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1080, 'h': 1350, 'resize': 'fit'},
#        'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 960, 'h': 1200, 'resize': 'fit'}},
#       'source_status_id': 1591101988766642176,
#       'source_status_id_str': '1591101988766642176',
#       'source_user_id': 279966754,
#       'source_user_id_str': '279966754'}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 545152489,
#     'id_str': '545152489',
#     'name': 'Henry',
#     'screen_name': 'oakzz_',
#     'location': '',
#     'description': 'views expressed are my own',
#     'url': 'https://t.co/3XCRN3Mowu',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/3XCRN3Mowu',
#         'expanded_url': 'http://Instagram.com/oakz_',
#         'display_url': 'Instagram.com/oakz_',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1065,
#     'friends_count': 797,
#     'listed_count': 3,
#     'created_at': 'Wed Apr 04 14:03:47 +0000 2012',
#     'favourites_count': 3327,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 45140,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1579477167393705986/Vm0SpNC3_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1579477167393705986/Vm0SpNC3_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/545152489/1664585079',
#     'profile_link_color': '2FC2EF',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 11 16:14:10 +0000 2022',
#     'id': 1591101988766642176,
#     'id_str': '1591101988766642176',
#     'text': 'Worldcup Qatar 🇶🇦 2022! \nWe coming! 🧘🏽\u200d♂️🙏🏽 https://t.co/MrC3uI2aps',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1591101981887799297,
#        'id_str': '1591101981887799297',
#        'indices': [44, 67],
#        'media_url': 'http://pbs.twimg.com/media/FhS60o_XoAECw0p.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FhS60o_XoAECw0p.jpg',
#        'url': 'https://t.co/MrC3uI2aps',
#        'display_url': 'pic.twitter.com/MrC3uI2aps',
#        'expanded_url': 'https://twitter.com/Memphis/status/1591101988766642176/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1080, 'h': 1350, 'resize': 'fit'},
#         'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 960, 'h': 1200, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1591101981887799297,
#        'id_str': '1591101981887799297',
#        'indices': [44, 67],
#        'media_url': 'http://pbs.twimg.com/media/FhS60o_XoAECw0p.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FhS60o_XoAECw0p.jpg',
#        'url': 'https://t.co/MrC3uI2aps',
#        'display_url': 'pic.twitter.com/MrC3uI2aps',
#        'expanded_url': 'https://twitter.com/Memphis/status/1591101988766642176/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1080, 'h': 1350, 'resize': 'fit'},
#         'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 960, 'h': 1200, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 279966754,
#      'id_str': '279966754',
#      'name': 'Memphis Depay',
#      'screen_name': 'Memphis',
#      'location': 'Worldwide',
#      'description': '@memphislions',
#      'url': 'https://t.co/dNz2itmVg2',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/dNz2itmVg2',
#          'expanded_url': 'http://www.memphisdepay.com',
#          'display_url': 'memphisdepay.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2555339,
#      'friends_count': 68,
#      'listed_count': 2227,
#      'created_at': 'Sun Apr 10 11:00:50 +0000 2011',
#      'favourites_count': 124,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 5324,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '080C12',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1523716576175869952/WqfTT12-_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1523716576175869952/WqfTT12-_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/279966754/1655951454',
#      'profile_link_color': '19101A',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'D61717',
#      'profile_text_color': '140813',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 258,
#     'favorite_count': 5988,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 258,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.141,
#   'max_id': 1591164080412577794,
#   'max_id_str': '1591164080412577794',
#   'next_results': '?max_id=1591163324414144512&q=qatar&lang=en&count=100&include_entities=1',
#   'query': 'qatar',
#   'refresh_url': '?since_id=1591164080412577794&q=qatar&lang=en&include_entities=1',
#   'count': 100,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
import pandas as pd

# %%
all_items=results['statuses']

# %%
df=pd.DataFrame(all_items)

# %%
df.sample(5)
# Out:
#                         created_at                   id               id_str  \
# 42  Fri Nov 11 21:31:36 +0000 2022  1591181875212865536  1591181875212865536
# 35  Fri Nov 11 21:31:42 +0000 2022  1591181902060605440  1591181902060605440
# 6   Fri Nov 11 21:32:26 +0000 2022  1591182086550876160  1591182086550876160
# 80  Fri Nov 11 21:30:42 +0000 2022  1591181648267448322  1591181648267448322
# 47  Fri Nov 11 21:31:29 +0000 2022  1591181847735803922  1591181847735803922
#
#                                                  text  truncated  \
# 42  @ktjdiary What a thick! Read a book or are the...      False
# 35  RT @ardenthistorian: Musks behaviour makes no ...      False
# 6   RT @kay_mahapa: What Qatar did is what qualifi...      False
# 80  @beyoncevision @ThePopTingz Germany (2006) did...       True
# 47                                   Road to Qatar 🇧🇷      False
#
#                                              entities  \
# 42  {'hashtags': [], 'symbols': [], 'user_mentions...
# 35  {'hashtags': [], 'symbols': [], 'user_mentions...
# 6   {'hashtags': [], 'symbols': [], 'user_mentions...
# 80  {'hashtags': [], 'symbols': [], 'user_mentions...
# 47  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                              metadata  \
# 42  {'iso_language_code': 'en', 'result_type': 're...
# 35  {'iso_language_code': 'en', 'result_type': 're...
# 6   {'iso_language_code': 'en', 'result_type': 're...
# 80  {'iso_language_code': 'en', 'result_type': 're...
# 47  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                source  in_reply_to_status_id  \
# 42  <a href="http://twitter.com/download/iphone" r...           1.591074e+18
# 35  <a href="http://twitter.com/download/iphone" r...                    NaN
# 6   <a href="http://twitter.com/download/android" ...                    NaN
# 80  <a href="http://twitter.com/download/android" ...           1.591180e+18
# 47  <a href="http://twitter.com/download/android" ...                    NaN
#
#    in_reply_to_status_id_str  ...  retweet_count favorite_count favorited  \
# 42       1591073922304606209  ...              0              0     False
# 35                      None  ...             79              0     False
# 6                       None  ...              4              0     False
# 80       1591180354542800896  ...              0              0     False
# 47                      None  ...              0              0     False
#
#    retweeted lang extended_entities possibly_sensitive quoted_status_id  \
# 42     False   en               NaN                NaN              NaN
# 35     False   en               NaN                NaN              NaN
# 6      False   en               NaN                NaN              NaN
# 80     False   en               NaN                NaN              NaN
# 47     False   en               NaN                NaN              NaN
#
#    quoted_status_id_str  quoted_status
# 42                  NaN            NaN
# 35                  NaN            NaN
# 6                   NaN            NaN
# 80                  NaN            NaN
# 47                  NaN            NaN
#
# [5 rows x 30 columns]

# %%
users=pd.DataFrame(d["user"] for d in results["statuses"])

# %%
users.head()
# Out:
#                     id               id_str                name  \
# 0   998443021837459456   998443021837459456      O L A M I D E⚪
# 1           4920596656           4920596656  Danny Obeng Boamah
# 2   922145932388503553   922145932388503553        Diddy Danson
# 3  1183408276018520064  1183408276018520064              tony 🎀
# 4  1590336212887560195  1590336212887560195     Mustofa Mustofa
#
#        screen_name                       location  \
# 0         Olie_Cee
# 1    ObengDaniel93                sunyani  Area 4
# 2      mike_danson           Greater Accra, Ghana
# 3         jhversee   – no 66 daesangs no opinion
# 4  Mustofa60018335
#
#                        description                      url  \
# 0     keeping it real and simple 💯                     None
# 1                                                      None
# 2                PEACE ✌🏿& UNITY✊🏿                     None
# 3  bts, bad bunny ft. lana del rey  https://t.co/bk5qFGFtog
# 4                                                      None
#
#                                             entities  protected  \
# 0                      {'description': {'urls': []}}      False
# 1                      {'description': {'urls': []}}      False
# 2                      {'description': {'urls': []}}      False
# 3  {'url': {'urls': [{'url': 'https://t.co/bk5qFG...      False
# 4                      {'description': {'urls': []}}      False
#
#    followers_count  ...  profile_text_color  profile_use_background_image  \
# 0             5571  ...              333333                          True
# 1              329  ...              333333                          True
# 2            26064  ...              333333                          True
# 3             4976  ...              333333                          True
# 4                1  ...              333333                          True
#
#   has_extended_profile  default_profile default_profile_image following  \
# 0                 True             True                 False      None
# 1                 True             True                 False      None
# 2                False             True                 False      None
# 3                False             True                 False      None
# 4                 True             True                  True      None
#
#    follow_request_sent  notifications  translator_type withheld_in_countries
# 0                 None           None             none                    []
# 1                 None           None             none                    []
# 2                 None           None             none                    []
# 3                 None           None             none                    []
# 4                 None           None             none                    []
#
# [5 rows x 43 columns]

# %%
tdf=df.merge(users,left_index=True,right_index=True)

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 73 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   created_at_x                        100 non-null    object
#  1   id_x                                100 non-null    int64
#  2   id_str_x                            100 non-null    object
#  3   text                                100 non-null    object
#  4   truncated                           100 non-null    bool
#  5   entities_x                          100 non-null    object
#  6   metadata                            100 non-null    object
#  7   source                              100 non-null    object
#  8   in_reply_to_status_id               10 non-null     float64
#  9   in_reply_to_status_id_str           10 non-null     object
#  10  in_reply_to_user_id                 11 non-null     float64
#  11  in_reply_to_user_id_str             11 non-null     object
#  12  in_reply_to_screen_name             11 non-null     object
#  13  user                                100 non-null    object
#  14  geo                                 0 non-null      object
#  15  coordinates                         0 non-null      object
#  16  place                               0 non-null      object
#  17  contributors                        0 non-null      object
#  18  retweeted_status                    80 non-null     object
#  19  is_quote_status                     100 non-null    bool
#  20  retweet_count                       100 non-null    int64
#  21  favorite_count                      100 non-null    int64
#  22  favorited                           100 non-null    bool
#  23  retweeted                           100 non-null    bool
#  24  lang_x                              100 non-null    object
#  25  extended_entities                   27 non-null     object
#  26  possibly_sensitive                  33 non-null     object
#  27  quoted_status_id                    1 non-null      float64
#  28  quoted_status_id_str                1 non-null      object
#  29  quoted_status                       1 non-null      object
#  30  id_y                                100 non-null    int64
#  31  id_str_y                            100 non-null    object
#  32  name                                100 non-null    object
#  33  screen_name                         100 non-null    object
#  34  location                            100 non-null    object
#  35  description                         100 non-null    object
#  36  url                                 24 non-null     object
#  37  entities_y                          100 non-null    object
#  38  protected                           100 non-null    bool
#  39  followers_count                     100 non-null    int64
#  40  friends_count                       100 non-null    int64
#  41  listed_count                        100 non-null    int64
#  42  created_at_y                        100 non-null    object
#  43  favourites_count                    100 non-null    int64
#  44  utc_offset                          0 non-null      object
#  45  time_zone                           0 non-null      object
#  46  geo_enabled                         100 non-null    bool
#  47  verified                            100 non-null    bool
#  48  statuses_count                      100 non-null    int64
#  49  lang_y                              0 non-null      object
#  50  contributors_enabled                100 non-null    bool
#  51  is_translator                       100 non-null    bool
#  52  is_translation_enabled              100 non-null    bool
#  53  profile_background_color            100 non-null    object
#  54  profile_background_image_url        45 non-null     object
#  55  profile_background_image_url_https  45 non-null     object
#  56  profile_background_tile             100 non-null    bool
#  57  profile_image_url                   100 non-null    object
#  58  profile_image_url_https             100 non-null    object
#  59  profile_banner_url                  82 non-null     object
#  60  profile_link_color                  100 non-null    object
#  61  profile_sidebar_border_color        100 non-null    object
#  62  profile_sidebar_fill_color          100 non-null    object
#  63  profile_text_color                  100 non-null    object
#  64  profile_use_background_image        100 non-null    bool
#  65  has_extended_profile                100 non-null    bool
#  66  default_profile                     100 non-null    bool
#  67  default_profile_image               100 non-null    bool
#  68  following                           0 non-null      object
#  69  follow_request_sent                 0 non-null      object
#  70  notifications                       0 non-null      object
#  71  translator_type                     100 non-null    object
#  72  withheld_in_countries               100 non-null    object
# dtypes: bool(15), float64(3), int64(9), object(46)
# memory usage: 46.9+ KB

# %%
tdf.location.value_counts().plot(kind='bar',figsize=(10,6));
# Out:
# C:\Users\Utilisateur\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127801 (\N{ROSE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Utilisateur\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Utilisateur\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127468 (\N{REGIONAL INDICATOR SYMBOL LETTER G}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Utilisateur\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127463 (\N{REGIONAL INDICATOR SYMBOL LETTER B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Utilisateur\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127988 (\N{WAVING BLACK FLAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Utilisateur\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 917607 (\N{TAG LATIN SMALL LETTER G}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Utilisateur\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 917602 (\N{TAG LATIN SMALL LETTER B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Utilisateur\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 917605 (\N{TAG LATIN SMALL LETTER E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Utilisateur\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 917614 (\N{TAG LATIN SMALL LETTER N}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Utilisateur\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 917631 (\N{CANCEL TAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Utilisateur\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128588 (\N{PERSON RAISING BOTH HANDS IN CELEBRATION}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Sentiment Analysis

# %%
from textblob import TextBlob

# %%
def detect_sentiment(text):
    return TextBlob(text).sentiment.polarity

# %%
df2=tdf[["text"]]

# %%
df2.sample(5)
# Out:
#                                                  text
# 42  @ktjdiary What a thick! Read a book or are the...
# 18  RT @goatnftio: 🔥WanDa X GOAT DAO🔥\nGOAT DAO of...
# 23  Lenarduzzi came close in ‘86. Who will end Can...
# 90  RT @brfootball: Brazil fans are already taking...
# 19  RT @SaddickAdams: Issah Amadu has been Asante ...

# %%
df2["sentiment"]=df2["text"].apply(detect_sentiment)
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_3192\1909004749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["sentiment"]=df2["text"].apply(detect_sentiment)

# %%
df2.head()
# Out:
#                                                 text  sentiment
# 0  RT @instablog9ja: Kizz Daniel has been schedul...        0.0
# 1  RT @Blue_Footy: Trossard on Chelsea transfer r...        0.0
# 2  RT @brfootball: Brazil fans are already taking...        0.0
# 3  RT @zonequal: the world cup is literally in 9 ...        0.0
# 4  RT @goatnftio: 🔥WanDa X GOAT DAO🔥\nGOAT DAO of...        0.0

# %%
df2.sentiment.value_counts()
# Out:
#  0.000000    67
#  0.200000     5
# -0.500000     4
#  0.250000     4
#  0.068182     3
# -0.250000     2
# -0.100000     2
#  0.300000     1
# -0.066667     1
#  0.375000     1
# -0.666667     1
# -0.375000     1
#  0.069444     1
# -0.007143     1
# -0.166667     1
#  0.612121     1
#  0.136364     1
# -0.208333     1
#  1.000000     1
# -0.050000     1
# Name: sentiment, dtype: int64

# %%
df2['text']=df2['text'].str.lower()
df2['text']=df2['text'].str.replace('[^\w\s]','')
df2['text']=df2['text'].str.replace('\d+','')
df2['text']=df2['text'].str.replace('\n',' ').replace('\r',' ')
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_3192\183491121.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['text']=df2['text'].str.lower()
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_3192\183491121.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['text']=df2['text'].str.replace('[^\w\s]','')
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_3192\183491121.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['text']=df2['text'].str.replace('[^\w\s]','')
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_3192\183491121.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['text']=df2['text'].str.replace('\d+','')
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_3192\183491121.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['text']=df2['text'].str.replace('\d+','')
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_3192\183491121.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['text']=df2['text'].str.replace('\n',' ').replace('\r',' ')

# %%
from wordcloud import STOPWORDS
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
def wc(data,bgcolor):
    plt.figure(figsize=(10,10))
    mask=np.array(Image.open("wcup.png"))
    wc=WordCloud(background_color=bgcolor,stopwords=STOPWORDS)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis("off")

# %%
wc(df2.text,'white')

# %%
# 1=positive
# 2=negative
# 0=Neutral

def sentiment2(sent):
    if sent<-0.02:
        return 2
    elif sent>0.02:
        return 1
    else:
        return 0

# %%
df2["sent"]=df2["sentiment"].apply(sentiment2)
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_3192\3383788003.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["sent"]=df2["sentiment"].apply(sentiment2)

# %%
df2.head()
# Out:
#                                                 text  sentiment  sent
# 0  rt instablogja kizz daniel has been scheduled ...        0.0     0
# 1  rt blue_footy trossard on chelsea transfer rum...        0.0     0
# 2  rt brfootball brazil fans are already taking o...        0.0     0
# 3  rt zonequal the world cup is literally in  day...        0.0     0
# 4  rt goatnftio wanda x goat dao goat dao of mess...        0.0     0

# %%
import seaborn as sns

# %%
sns.countplot(x=df2.sent);

# %%
x=df2.text
y=df2.sent

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
vect=CountVectorizer(stop_words="english")

# %%
x=vect.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=.15)

# %%
mb=MultinomialNB()

# %%
tahmin=mb.fit(x_train,y_train).predict(x_test)

# %%
accuracy_score(tahmin,y_test)
# Out:
# 0.6666666666666666

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
d=DecisionTreeClassifier()

# %%
d.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
tahmin2=d.predict(x_test)

# %%
accuracy_score(tahmin2,y_test)
# Out:
# 0.9333333333333333
